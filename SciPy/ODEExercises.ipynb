# %% [markdown]
# # ODE Exercises

# %%
# %pylab inline
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ### Question 1

# %% [markdown]
# (a) See what happens to the period of the pendulum as you change the initial angle of release. Plot θ vs t for 5 different initial angles, θ0 , spanning 0 to π. (i.e. 0, π/4 , π/2 , 3π/4 , and π ). Put them all on the same plot. What happens to the period of the pendulum as the initial angle increases from π/4 to 3π/4? What happens to the trajectory when the initial angle is 0 and π ?

# %%
def deriv(theta_current,t):  # return derivatives of the array theta
    g = 9.8 #m/s^2
    ell = 0.5 #m
    theta = theta_current[0]
    omega = theta_current[1]
    dtheta = omega
    domega = -(g/ell)*np.sin(theta)
    return np.array([ dtheta, domega ])

# %%
t = np.arange(0.,10.+0.01,0.01)
omega0 = 0. #starting from rest, omega = 0

theta = []
th0 = arange(0,np.pi+np.pi/4,np.pi/4)

theta_init = np.array([th0[0], omega0]) # initial values
theta = odeint(deriv,theta_init,t) 

theta_init = np.array([th0[1], omega0]) # initial values
theta1 = odeint(deriv,theta_init,t)

theta_init = np.array([th0[2], omega0]) # initial values
theta2 = odeint(deriv,theta_init,t)

theta_init = np.array([th0[3], omega0]) # initial values
theta3 = odeint(deriv,theta_init,t)

theta_init = np.array([th0[4], omega0]) # initial values
theta4 = odeint(deriv,theta_init,t)

plt.plot(t,theta[:,0],'r',label="theta0 = 0")
plt.plot(t,theta1[:,0],'b',label="theta0 = pi/4")
plt.plot(t,theta2[:,0],'g',label="theta0 = pi/2")
plt.plot(t,theta3[:,0],'k',label="theta0 = 3pi/4")
plt.plot(t,theta4[:,0],'m',label="theta0 = pi")
plt.xlabel(r'$t (seconds)$',fontsize=20)
plt.ylabel(r'$\theta (rad)$',fontsize=20)
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# As the initial angle increases from pi/4 to 3pi/4, the period increases. When the inital angle is 0 and pi, the pendulum does not move.

# %% [markdown]
# (b) Make plots of θ vs. t, ω vs. t, and ω vs. θ (the so-called "phase plot") for θ0 = 0.95π. Look carefully at their behavior. What is going on in these figures?

# %%
th0 = 0.98*np.pi
omega0 = 0.

theta_init = np.array([th0, omega0]) # initial values
theta = odeint(deriv,theta_init,t,rtol=1.49012e-13,atol=1.49012e-13) 

plt.plot(t,theta[:,0])
plt.xlabel(r'$t (seconds)$',fontsize=20);
plt.ylabel(r'$\theta (rad)$',fontsize=20);
figure()
plt.plot(t,theta[:,1])
plt.xlabel(r'$t (seconds)$',fontsize=20);
plt.ylabel(r'$\omega (rad/s)$',fontsize=20);
figure()
plt.plot(theta[:,0],theta[:,1])
plt.xlabel(r'$\theta (rad)$',fontsize=20);
plt.ylabel(r'$\omega (rad/s)$',fontsize=20);

# %% [markdown]
# (c) For the θ0 = 0.95π case, check that energy is conserved by plotting E/m vs. t (where E/m=gℓ(1−cos(θ))+12ℓ2ω2 ).
# Is the energy a constant? If not, then the computational errors are producing a non-physical loss (or gain) of energy. Review the documentation for odeint and change the error tolerance value to a tighter number.

# %%
omega = theta[:,1]
Theta = theta[:,0]
g = 9.8
L = 0.5
func = lambda omega,Theta : g*L*(1.-np.cos(Theta)) + (1./2.)*(L**2.)*(omega**2.)
Edm = func(omega,Theta) 
plt.plot(t,Edm);
plt.ylim(9.5,10)
plt.xlabel(r'$t (seconds)$',fontsize=20);
plt.ylabel(r'$E/m $',fontsize=20);

# %% [markdown]
# (d) Now look at what happens if we start the pendulum straight up, θ=π. Go for at least 50 s. Be sure to describe what happens numerically according to the θ vs. t, ω vs. t and E/m vs. t plots. What do you think should happen? What happens if you change the error tolerance on odeint? How does this compare to a nearly vertical pendulum: θ0=π−0.000001 ?

# %%
theta0 = np.pi
t = np.arange(0.,50.+0.01,0.01)

theta_init = np.array([theta0, omega0]) # initial values
theta = odeint(deriv,theta_init,t,rtol=1.49012e-10,atol=1.49012e-10) 

figure()
plt.plot(t,theta[:,0])
plt.xlabel(r'$t (seconds)$',fontsize=20);
plt.ylabel(r'$\theta (rad)$',fontsize=20);

figure()
plt.plot(t,theta[:,1])
plt.xlabel(r'$t (seconds)$',fontsize=20);
plt.ylabel(r'$\omega (rad/s)$',fontsize=20);

omega = theta[:,1]
Theta = theta[:,0]
func = lambda omega,Theta : g*L*(1.-np.cos(Theta)) + (1./2.)*(L**2.)*(omega**2.)
Edm = func(omega,Theta)

figure()
plt.plot(t,Edm);
plt.ylim(9.5,10)
plt.xlabel(r'$t (seconds)$',fontsize=20);
plt.ylabel(r'$E/m $',fontsize=20);


theta0 = np.pi-0.000001

theta_init = np.array([theta0, omega0]) # initial values
theta = odeint(deriv,theta_init,t,rtol=1.49012e-10,atol=1.49012e-10) 

figure()
plt.plot(t,theta[:,0])
plt.xlabel(r'$t (seconds)$',fontsize=20);
plt.ylabel(r'$\theta (rad)$',fontsize=20);

figure()
plt.plot(t,theta[:,1])
plt.xlabel(r'$t (seconds)$',fontsize=20);
plt.ylabel(r'$\omega (rad/s)$',fontsize=20);

omega = theta[:,1]
Theta = theta[:,0]
func = lambda omega,Theta : g*L*(1.-np.cos(Theta)) + (1./2.)*(L**2.)*(omega**2.)
Edm = func(omega,Theta)
figure()
plt.plot(t,Edm);
plt.ylim(9.5,10)
plt.xlabel(r'$t (seconds)$',fontsize=20);
plt.ylabel(r'$E/m $',fontsize=20);
plt.show()

# %% [markdown]
# ### Question 2

# %% [markdown]
# (a) Use Euler's method (not odeint) to solve the following first-order differential equation with given initial condition y(0) = 0.
# dydx=x+2y
# Find the value of y when x = 1, y(1), using two different step sizes: 0.25 then 0.02.

# %% [markdown]
# (b) Plot the results from part (a) for the two different step sizes with the exact solution
# y=0.25e2x−0.5x−0.25
# on one plot. Include a legend. Which step size gives a more accurate result?

# %%
def EulerODE(dx):
    xmax = 10 # maximum time
    nsteps = int(xmax/dx)
    x = np.zeros(nsteps)
    dy = np.zeros(nsteps)
    y = np.zeros(nsteps)
 
    # set initial conditions, redundant in this example
    x[0] = 0.
    y[0] = 0.

    for i in range(len(x)-1):
        x[i+1] = x[i] + dx
        dy[i+1] = x[i] + 2*y[i]
        y[i+1] = y[i] + dy[i]*dx
     
    indexx = np.where(x==1)
    
    y_exact = lambda x : 0.25*exp(2*x) - 0.5*x - 0.25 
    exact = y_exact(x)
    
    figure()
    plt.plot(x,y,label='Euler')
    plt.plot(x,exact,label='Exact');
    plt.xlabel(r'$ x $',fontsize=20);
    plt.ylabel(r'$ y $',fontsize=20);
    plt.title('spacing = ' + str(dx));
    plt.legend()
    
    return x,y,y[indexx]

# %%
EulerODE(0.25)
EulerODE(0.02)
# Out:
# (array([ 0.  ,  0.02,  0.04,  0.06,  0.08,  0.1 ,  0.12,  0.14,  0.16,
#          0.18,  0.2 ,  0.22,  0.24,  0.26,  0.28,  0.3 ,  0.32,  0.34,
#          0.36,  0.38,  0.4 ,  0.42,  0.44,  0.46,  0.48,  0.5 ,  0.52,
#          0.54,  0.56,  0.58,  0.6 ,  0.62,  0.64,  0.66,  0.68,  0.7 ,
#          0.72,  0.74,  0.76,  0.78,  0.8 ,  0.82,  0.84,  0.86,  0.88,
#          0.9 ,  0.92,  0.94,  0.96,  0.98,  1.  ,  1.02,  1.04,  1.06,
#          1.08,  1.1 ,  1.12,  1.14,  1.16,  1.18,  1.2 ,  1.22,  1.24,
#          1.26,  1.28,  1.3 ,  1.32,  1.34,  1.36,  1.38,  1.4 ,  1.42,
#          1.44,  1.46,  1.48,  1.5 ,  1.52,  1.54,  1.56,  1.58,  1.6 ,
#          1.62,  1.64,  1.66,  1.68,  1.7 ,  1.72,  1.74,  1.76,  1.78,
#          1.8 ,  1.82,  1.84,  1.86,  1.88,  1.9 ,  1.92,  1.94,  1.96,
#          1.98,  2.  ,  2.02,  2.04,  2.06,  2.08,  2.1 ,  2.12,  2.14,
#          2.16,  2.18,  2.2 ,  2.22,  2.24,  2.26,  2.28,  2.3 ,  2.32,
#          2.34,  2.36,  2.38,  2.4 ,  2.42,  2.44,  2.46,  2.48,  2.5 ,
#          2.52,  2.54,  2.56,  2.58,  2.6 ,  2.62,  2.64,  2.66,  2.68,
#          2.7 ,  2.72,  2.74,  2.76,  2.78,  2.8 ,  2.82,  2.84,  2.86,
#          2.88,  2.9 ,  2.92,  2.94,  2.96,  2.98,  3.  ,  3.02,  3.04,
#          3.06,  3.08,  3.1 ,  3.12,  3.14,  3.16,  3.18,  3.2 ,  3.22,
#          3.24,  3.26,  3.28,  3.3 ,  3.32,  3.34,  3.36,  3.38,  3.4 ,
#          3.42,  3.44,  3.46,  3.48,  3.5 ,  3.52,  3.54,  3.56,  3.58,
#          3.6 ,  3.62,  3.64,  3.66,  3.68,  3.7 ,  3.72,  3.74,  3.76,
#          3.78,  3.8 ,  3.82,  3.84,  3.86,  3.88,  3.9 ,  3.92,  3.94,
#          3.96,  3.98,  4.  ,  4.02,  4.04,  4.06,  4.08,  4.1 ,  4.12,
#          4.14,  4.16,  4.18,  4.2 ,  4.22,  4.24,  4.26,  4.28,  4.3 ,
#          4.32,  4.34,  4.36,  4.38,  4.4 ,  4.42,  4.44,  4.46,  4.48,
#          4.5 ,  4.52,  4.54,  4.56,  4.58,  4.6 ,  4.62,  4.64,  4.66,
#          4.68,  4.7 ,  4.72,  4.74,  4.76,  4.78,  4.8 ,  4.82,  4.84,
#          4.86,  4.88,  4.9 ,  4.92,  4.94,  4.96,  4.98,  5.  ,  5.02,
#           9.58352154e+06,   9.95264524e+06,   1.03359863e+07,
#           1.07340923e+07,   1.11475319e+07,   1.15768958e+07,
#           1.20227973e+07,   1.24858733e+07,   1.29667854e+07,
#           1.34662205e+07,   1.39848921e+07,   1.45235411e+07,
#           1.50829369e+07,   1.56638788e+07,   1.62671964e+07,
#           1.68937518e+07,   1.75444398e+07,   1.82201901e+07,
#           1.89219679e+07,   1.96507757e+07,   2.04076546e+07,
#           2.11936858e+07,   2.20099922e+07,   2.28577398e+07,
#           2.37381397e+07,   2.46524495e+07,   2.56019753e+07,
#           2.65880734e+07,   2.76121526e+07,   2.86756758e+07,
#           2.97801621e+07,   3.09271893e+07,   3.21183960e+07,
#           3.33554838e+07,   3.46402198e+07,   3.59744393e+07,
#           3.73600483e+07,   3.87990261e+07]),
#  array([], dtype=float64))

# %% [markdown]
# (c) Now solve the same problem using Euler-Cromer and the Midpoint method for the same pair of step sizes and plot the results along with the exact solution. Then also plot the difference between the approximate numerical solutions and the exact solution. Which combination of method and step-size gives the best result?)

# %%
def EulerCromerODE(dx):
    xmax = 10 # maximum time
    nsteps = int(xmax/dx)
    x = np.zeros(nsteps)
    dy = np.zeros(nsteps)
    y = np.zeros(nsteps)
 
    # set initial conditions, redundant in this example
    x[0] = 0.
    y[0] = 0.

    for i in range(len(x)-1):
        x[i+1] = x[i] + dx
        dy[i+1] = x[i] + 2*y[i]
        y[i+1] = y[i] + dy[i+1]*dx
    
    y_exact = lambda x : 0.25*exp(2*x) - 0.5*x - 0.25 
    exact = y_exact(x)
    error = abs(exact-y)
    
    figure()
    plt.plot(x,y,label='Euler')
    plt.plot(x,exact,label='Exact');
    plt.xlabel(r'$ x $',fontsize=20);
    plt.ylabel(r'$ y $',fontsize=20);
    plt.title('spacing = ' + str(dx));
    plt.legend()
    
    figure()
    plt.plot(x,error)
    plt.xlabel(r'$ x $',fontsize=20);
    plt.ylabel(r'$ error $',fontsize=20);
    plt.title('Approximate - Exact');
    
    return x,y

# %%
EulerCromerODE(0.25)
EulerCromerODE(0.02)
# Out:
# (array([ 0.  ,  0.02,  0.04,  0.06,  0.08,  0.1 ,  0.12,  0.14,  0.16,
#          0.18,  0.2 ,  0.22,  0.24,  0.26,  0.28,  0.3 ,  0.32,  0.34,
#          0.36,  0.38,  0.4 ,  0.42,  0.44,  0.46,  0.48,  0.5 ,  0.52,
#          0.54,  0.56,  0.58,  0.6 ,  0.62,  0.64,  0.66,  0.68,  0.7 ,
#          0.72,  0.74,  0.76,  0.78,  0.8 ,  0.82,  0.84,  0.86,  0.88,
#          0.9 ,  0.92,  0.94,  0.96,  0.98,  1.  ,  1.02,  1.04,  1.06,
#          1.08,  1.1 ,  1.12,  1.14,  1.16,  1.18,  1.2 ,  1.22,  1.24,
#          1.26,  1.28,  1.3 ,  1.32,  1.34,  1.36,  1.38,  1.4 ,  1.42,
#          1.44,  1.46,  1.48,  1.5 ,  1.52,  1.54,  1.56,  1.58,  1.6 ,
#          1.62,  1.64,  1.66,  1.68,  1.7 ,  1.72,  1.74,  1.76,  1.78,
#           5.42424190e+05,   5.64121307e+05,   5.86686308e+05,
#           6.10153910e+05,   6.34560216e+05,   6.59942775e+05,
#           6.86340637e+05,   7.13794414e+05,   7.42346342e+05,
#           7.72040348e+05,   8.02922114e+05,   8.35039151e+05,
#           8.68440871e+05,   9.03178659e+05,   9.39305959e+05,
#           9.76878352e+05,   1.01595364e+06,   1.05659194e+06,
#           1.09885578e+06,   1.14281016e+06,   1.18852273e+06,
#           1.23606379e+06,   1.28550650e+06,   1.33692692e+06,
#           1.39040415e+06,   1.44602048e+06,   1.50386145e+06,
#           1.56401607e+06,   1.62657687e+06,   1.69164011e+06,
#           1.75930587e+06,   1.82967827e+06,   1.90286556e+06,
#           1.97898035e+06,   2.05813972e+06,   2.14046547e+06,
#           2.22608425e+06,   2.31512779e+06,   2.40773306e+06,
#           2.50404255e+06,   2.60420442e+06,   2.70837276e+06,
#           2.81670783e+06,   2.92937631e+06,   3.04655153e+06,
#           3.16841376e+06,   3.29515047e+06,   3.42695666e+06,
#           3.56403510e+06,   3.70659667e+06,   3.85486070e+06,
#           4.00905530e+06,   4.16941768e+06,   4.33619456e+06,
#           4.50964251e+06,   4.69002838e+06,   4.87762969e+06,
#           5.07273504e+06,   5.27564462e+06,   5.48667057e+06,
#           5.70613757e+06,   5.93438325e+06,   6.17175875e+06,
#           6.41862927e+06,   6.67537462e+06,   6.94238978e+06,
#           7.22008554e+06,   7.50888914e+06,   7.80924488e+06,
#           8.12161485e+06,   8.44647962e+06,   8.78433898e+06,
#           9.13571272e+06,   9.50114141e+06,   9.88118724e+06,
#           1.02764349e+07,   1.06874925e+07,   1.11149924e+07,
#           1.15595922e+07,   1.20219761e+07,   1.25028553e+07,
#           1.30029697e+07,   1.35230887e+07,   1.40640124e+07,
#           1.46265731e+07,   1.52116362e+07,   1.58201018e+07,
#           1.64529061e+07,   1.71110225e+07,   1.77954636e+07,
#           1.85072823e+07,   1.92475738e+07,   2.00174770e+07,
#           2.08181762e+07,   2.16509035e+07,   2.25169398e+07,
#           2.34176176e+07,   2.43543224e+07,   2.53284955e+07,
#           2.63416355e+07,   2.73953012e+07,   2.84911134e+07,
#           2.96307581e+07,   3.08159886e+07,   3.20486284e+07,
#           3.33305737e+07,   3.46637968e+07,   3.60503489e+07,
#           3.74923630e+07,   3.89920577e+07,   4.05517402e+07,
#           4.21738101e+07,   4.38607626e+07,   4.56151933e+07,
#           4.74398013e+07,   4.93373935e+07,   5.13108895e+07,
#           5.33633252e+07,   5.54978584e+07,   5.77177730e+07,
#           6.00264841e+07,   6.24275436e+07,   6.49246456e+07,
#           6.75216316e+07,   7.02224971e+07,   7.30313971e+07,
#           7.59526532e+07,   7.89907596e+07]))

# %%
def MidpointODE(dx):
    xmax = 10 # maximum time
    nsteps = int(xmax/dx)
    x = np.zeros(nsteps)
    dy = np.zeros(nsteps)
    y = np.zeros(nsteps)
 
    # set initial conditions, redundant in this example
    x[0] = 0.
    y[0] = 0.

    for i in range(len(x)-1):
        x[i+1] = x[i] + dx
        dy[i+1] = x[i] + 2*y[i]
        y[i+1] = y[i] + (1./2.)*(dy[i+1]+dy[i])*dx
    
    y_exact = lambda x : 0.25*exp(2*x) - 0.5*x - 0.25 
    exact = y_exact(x)
    error = abs(exact-y)
    
    figure()
    plt.plot(x,y,label='Euler')
    plt.plot(x,exact,label='Exact');
    plt.xlabel(r'$ x $',fontsize=20);
    plt.ylabel(r'$ y $',fontsize=20);
    plt.title('spacing = ' + str(dx));
    plt.legend()
    
    figure()
    plt.plot(x,error)
    plt.xlabel(r'$ x $',fontsize=20);
    plt.ylabel(r'$ error $',fontsize=20);
    plt.title('Approximate - Exact');
    
    return x,y

# %%
MidpointODE(0.25)
MidpointODE(0.02)
# Out:
# (array([ 0.  ,  0.02,  0.04,  0.06,  0.08,  0.1 ,  0.12,  0.14,  0.16,
#          0.18,  0.2 ,  0.22,  0.24,  0.26,  0.28,  0.3 ,  0.32,  0.34,
#          0.36,  0.38,  0.4 ,  0.42,  0.44,  0.46,  0.48,  0.5 ,  0.52,
#          0.54,  0.56,  0.58,  0.6 ,  0.62,  0.64,  0.66,  0.68,  0.7 ,
#          0.72,  0.74,  0.76,  0.78,  0.8 ,  0.82,  0.84,  0.86,  0.88,
#          0.9 ,  0.92,  0.94,  0.96,  0.98,  1.  ,  1.02,  1.04,  1.06,
#          1.08,  1.1 ,  1.12,  1.14,  1.16,  1.18,  1.2 ,  1.22,  1.24,
#          1.26,  1.28,  1.3 ,  1.32,  1.34,  1.36,  1.38,  1.4 ,  1.42,
#          1.44,  1.46,  1.48,  1.5 ,  1.52,  1.54,  1.56,  1.58,  1.6 ,
#          1.62,  1.64,  1.66,  1.68,  1.7 ,  1.72,  1.74,  1.76,  1.78,
#          1.8 ,  1.82,  1.84,  1.86,  1.88,  1.9 ,  1.92,  1.94,  1.96,
#          1.98,  2.  ,  2.02,  2.04,  2.06,  2.08,  2.1 ,  2.12,  2.14,
#          2.16,  2.18,  2.2 ,  2.22,  2.24,  2.26,  2.28,  2.3 ,  2.32,
#          2.34,  2.36,  2.38,  2.4 ,  2.42,  2.44,  2.46,  2.48,  2.5 ,
#          2.52,  2.54,  2.56,  2.58,  2.6 ,  2.62,  2.64,  2.66,  2.68,
#          2.7 ,  2.72,  2.74,  2.76,  2.78,  2.8 ,  2.82,  2.84,  2.86,
#          2.88,  2.9 ,  2.92,  2.94,  2.96,  2.98,  3.  ,  3.02,  3.04,
#          3.06,  3.08,  3.1 ,  3.12,  3.14,  3.16,  3.18,  3.2 ,  3.22,
#          3.24,  3.26,  3.28,  3.3 ,  3.32,  3.34,  3.36,  3.38,  3.4 ,
#          3.42,  3.44,  3.46,  3.48,  3.5 ,  3.52,  3.54,  3.56,  3.58,
#          3.6 ,  3.62,  3.64,  3.66,  3.68,  3.7 ,  3.72,  3.74,  3.76,
#          3.78,  3.8 ,  3.82,  3.84,  3.86,  3.88,  3.9 ,  3.92,  3.94,
#          3.96,  3.98,  4.  ,  4.02,  4.04,  4.06,  4.08,  4.1 ,  4.12,
#          4.14,  4.16,  4.18,  4.2 ,  4.22,  4.24,  4.26,  4.28,  4.3 ,
#           5.25608096e+06,   5.46235469e+06,   5.67672358e+06,
#           5.89950532e+06,   6.13103008e+06,   6.37164096e+06,
#           6.62169456e+06,   6.88156145e+06,   7.15162674e+06,
#           7.43229069e+06,   7.72396921e+06,   8.02709459e+06,
#           8.34211605e+06,   8.66950044e+06,   9.00973295e+06,
#           9.36331780e+06,   9.73077899e+06,   1.01126611e+07,
#           1.05095301e+07,   1.09219741e+07,   1.13506044e+07,
#           1.17960561e+07,   1.22589895e+07,   1.27400906e+07,
#           1.32400724e+07,   1.37596758e+07,   1.42996710e+07,
#           1.48608581e+07,   1.54440689e+07,   1.60501676e+07,
#           1.66800525e+07,   1.73346571e+07,   1.80149515e+07,
#           1.87219438e+07,   1.94566819e+07,   2.02202546e+07,
#           2.10137936e+07,   2.18384747e+07,   2.26955203e+07,
#           2.35862004e+07,   2.45118350e+07,   2.54737959e+07,
#           2.64735087e+07,   2.75124550e+07,   2.85921744e+07,
#           2.97142672e+07,   3.08803962e+07,   3.20922897e+07,
#           3.33517436e+07,   3.46606245e+07,   3.60208720e+07,
#           3.74345021e+07,   3.89036098e+07,   4.04303723e+07,
#           4.20170521e+07,   4.36660008e+07,   4.53796620e+07,
#           4.71605755e+07,   4.90113804e+07,   5.09348198e+07,
#           5.29337440e+07,   5.50111154e+07]))

# %% [markdown]
# ### Question 3

# %% [markdown]
# We can use numerical solvers and widgets to explore the dynamics of a projectile that is subject to a drag force proportional to the square of its velocity - "quadratic drag".
# The force on the projectile is given by
# ∑F⃗ =ma⃗ =mg⃗ −cv2v^=mg⃗ −cvv⃗ =mg⃗ −cv2x+v2y−−−−−−√v⃗
# Where the second term is the drag force, in the direction opposite that of the velocity vector. Re-writing these in terms of the first-order differential equations for vx and vy gives
# mdvxdt=−cv2x+v2y−−−−−−√vx
# mdvydt=mg−cv2x+v2y−−−−−−√vy
# taking the positive y direction to be down. Notice that these are coupled equations. There are both vx and vy terms in each one. The drag coefficient c depends on the shape and density of the projectile. We can re-write this system of equations in terms of the terminal velocity - the point at which the gravitational force balances the drag force. This happens when mg=cv2. Let's denote the terminal velocity as vter=mg/c−−−−−√ and re-write our equations in terms of vter.
# dvxdt=−gmvxv2terv2x+v2y−−−−−−√
# dvydt=−gm(1+vyv2terv2x+v2y−−−−−−√)

# %% [markdown]
# (a) Create a derivative function to solve this system of equations and use odeint to solve it for a projectile fired at an angle of 50 degrees from the horizontal at an initial speed of 30 m/s. Track the projectile's motion over the time interval of 0 to 200 seconds and let (x0,y0) = (0,0). You'll have to calculate (vx0,vy0) from the information provided. Let vter=44 m/s. Plot the trajectory of the projectile (y vs. x) to see how far it can travel in the x direction before landing.

# %%
def deriv_projectile(current,t,g,Vter):  # return derivatives of the array theta
    Vx = current[0]
    Vy = current[1]
    x = current[2]
    y = current[3]
    dx = Vx
    dy = Vy
    dVx = -g*(Vx/(Vter**2.))*np.sqrt(Vx**2. + Vy**2.)
    dVy = -g*(1.+(Vy/(Vter**2.))*np.sqrt(Vx**2. + Vy**2.))
    return np.array([dVx,dVy,dx,dy])

# %%
V = 30
angle = (50./180)*np.pi

Vx0 = 30*np.cos(angle)
Vy0 = 30*np.sin(angle)
x0 = 0
y0 = 0
t = np.arange(0.,200.+0.1,0.1)
Vter = 44.
g = 9.8

init = np.array([Vx0,Vy0,x0,y0]) # initial values
output = odeint(deriv_projectile,init,t,args=(g,Vter)) 
x = output[:,2]
y = output[:,3]
plt.plot(x,y);
plt.ylim(0,40)
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# (b) Now create an interact object that uses sliders for the initial speed, terminal velocity, launch angle, and time. Have it plot two curves - one representing the solution with quadratic drag and the other in the absence of drag:
# x(t)=x0+vx0ty(t)=y0+vy0t−12gt2

# %%
from IPython.html.widgets import interact, interactive

# %%
V = 30
angle = 50
tmax = 200
global Vter
Vter = 44

def projectile(V,Vter,angle,tmax):
    g = 9.8
    angle = (angle/180)*np.pi
    t = np.arange(0.,tmax+0.1,0.1)
    Vx0 = V*np.cos(angle)
    Vy0 = V*np.sin(angle)
    x0 = 0
    y0 = 1.5
    init = np.array([Vx0,Vy0,x0,y0]) # initial values
    output = odeint(deriv_projectile,init,t,args=(g,Vter)) 
    x = output[:,2]
    y = output[:,3]
    
    x_ndrag = x0 + Vx0*t
    y_ndrag = y0 + Vy0*t - (1./2.)*g*(t**2)
    plt.plot(x,y,label='Quadratic Drag');
    plt.plot(x_ndrag,y_ndrag,label='No Drag');
    plt.ylim(0,100)
    plt.xlim(0,150)
    plt.xlabel('x')
    plt.ylabel('y')
    plt.legend()
    plt.show()



v = interact(projectile,V=(1.,100.),Vter=(1.,150.),angle=(0.,90.),tmax=(1.,200))

# %% [markdown]
# (c) Use your interact object to find 3 pairs of initial angle and speed needed for the following projectiles to reach a target 80 m away. How do the values change if there is no air resistance? Put your results in a table for easier reading.

# %%
from IPython.display import HTML

# %%
s = """<table>
<tr>
<th>Projectile</th>
<th>Inital Angle</th>
<th>Initial Speed</th>
<th>Inital Angle (no drag)</th>
<th>Initial Speed (no drag)</th>
</tr>
<tr>
<td>Golfball</td>
<td>46.7 degs</td>
<td>43.4 m/s</td>
<td>42 degs</td>
<td>28 m/s</td>
</tr>
<tr>
<td>Baseball</td>
<td>42.1 degs</td>
<td>33.1 m/s</td>
<td>40.6 degs</td>
<td>27.8 m/s</td>
</tr>
<tr>
<td>Pumpkin</td>
<td>41 degs</td>
<td>28.5 m/s</td>
<td>39.3 degs</td>
<td>27.9 m/s</td>
</tr>
</table>"""

# %%
h = HTML(s); h
# Out:
# <table>
# <tr>
# <th>Projectile</th>
# <th>Inital Angle</th>
# <th>Initial Speed</th>
# <th>Inital Angle (no drag)</th>
# <th>Initial Speed (no drag)</th>
# </tr>
# <tr>
# <td>Golfball</td>
# <td>46.7 degs</td>
# <td>43.4 m/s</td>
# <td>42 degs</td>
# <td>28 m/s</td>
# </tr>
# <tr>
# <td>Baseball</td>
# <td>42.1 degs</td>
# <td>33.1 m/s</td>
# <td>40.6 degs</td>
# <td>27.8 m/s</td>
# </tr>
# <tr>
# <td>Pumpkin</td>
# <td>41 degs</td>
# <td>28.5 m/s</td>
# <td>39.3 degs</td>
# <td>27.9 m/s</td>
# </tr>
# </table>
